# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KUMARAGURU-V-S/Lab-experiments/blob/main/DATA-ANALYTICS-AND-VISUALIZATION/Experiment-02-Data-Handling-and-Analysis/02b_pandas_dataframe.ipynb)
#
# # 02b_pandas_dataframe.py

# %%
# EX.NO: 2B - Working with Pandas DataFrames
# AIM: Perform data manipulation operations using Pandas

import pandas as pd
import numpy as np

# Create sample DataFrame
data = {
    'Name':  ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age':   [25, 30, 35, 28, 22],
    'Score': [88.5, 92.0, 78.3, 95.1, 85.6],
    'City':  ['Chennai', 'Mumbai', 'Delhi', 'Chennai', 'Mumbai']
}
df = pd.DataFrame(data)

print("--- DataFrame ---")
print(df)
print("\n--- Info ---")
df.info()
print("\n--- Summary Statistics ---")
print(df.describe())

# Handle missing values
df_nan = df.copy()
df_nan.loc[1, 'Score'] = None
print("\n--- DataFrame with NaN ---")
print(df_nan)
df_nan.fillna(df_nan['Score'].mean(), inplace=True)
print("\n--- After Filling NaN ---")
print(df_nan)

# Add computed column
df['Grade'] = df['Score'].apply(
    lambda x: 'A' if x >= 90 else ('B' if x >= 80 else 'C')
)
print("\n--- With Grade Column ---")
print(df)

# Filtering
print("\n--- Students with Score > 85 ---")
print(df[df['Score'] > 85])

# Groupby
print("\n--- Mean Score by City ---")
print(df.groupby('City')['Score'].mean())

# Sort
print("\n--- Sorted by Score (descending) ---")
print(df.sort_values('Score', ascending=False))

# Save to CSV
df.to_csv('processed_data.csv', index=False)
print("\nSaved to processed_data.csv")
# Out:
# --- DataFrame ---
#       Name  Age  Score     City
# 0    Alice   25   88.5  Chennai
# 1      Bob   30   92.0   Mumbai
# 2  Charlie   35   78.3    Delhi
# 3    David   28   95.1  Chennai
# 4      Eve   22   85.6   Mumbai
#
# --- Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   Score   5 non-null      float64
#  3   City    5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes
#
# --- Summary Statistics ---
#              Age      Score
# count   5.000000   5.000000
# mean   28.000000  87.900000
# std     4.949747   6.450969
# min    22.000000  78.300000
# 25%    25.000000  85.600000
# 50%    28.000000  88.500000
# 75%    30.000000  92.000000
# max    35.000000  95.100000
#
# --- DataFrame with NaN ---
#       Name  Age  Score     City
# 0    Alice   25   88.5  Chennai
# 1      Bob   30    NaN   Mumbai
# 2  Charlie   35   78.3    Delhi
# 3    David   28   95.1  Chennai
# 4      Eve   22   85.6   Mumbai
#
# --- After Filling NaN ---
#       Name  Age   Score     City
# 0    Alice   25  88.500  Chennai
# 1      Bob   30  86.875   Mumbai
# 2  Charlie   35  78.300    Delhi
# 3    David   28  95.100  Chennai
# 4      Eve   22  85.600   Mumbai
#
# --- With Grade Column ---
#       Name  Age  Score     City Grade
# 0    Alice   25   88.5  Chennai     B
# 1      Bob   30   92.0   Mumbai     A
# 2  Charlie   35   78.3    Delhi     C
# 3    David   28   95.1  Chennai     A
# 4      Eve   22   85.6   Mumbai     B
#
# --- Students with Score > 85 ---
#     Name  Age  Score     City Grade
# 0  Alice   25   88.5  Chennai     B
# 1    Bob   30   92.0   Mumbai     A
# 3  David   28   95.1  Chennai     A
# 4    Eve   22   85.6   Mumbai     B
#
# --- Mean Score by City ---
# City
# Chennai    91.8
# Delhi      78.3
# Mumbai     88.8
# Name: Score, dtype: float64
#
# --- Sorted by Score (descending) ---
#       Name  Age  Score     City Grade
# 3    David   28   95.1  Chennai     A
# 1      Bob   30   92.0   Mumbai     A
# 0    Alice   25   88.5  Chennai     B
# 4      Eve   22   85.6   Mumbai     B
# 2  Charlie   35   78.3    Delhi     C
#
# Saved to processed_data.csv
